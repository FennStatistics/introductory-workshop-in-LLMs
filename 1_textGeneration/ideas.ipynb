# %% [markdown]
# - prompting
#     + general set up
#     + zero
#     + 1 shot
#     + multiple shot
#     + reasoning of thought
# - summarize text
# - get associations
#     + include JSON schema (mimic CAM); save money / ressources; use R (https://github.com/samuelae/associatoR)
#
#
# - show influence of different hyperparameters / models

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate a normally distributed variable
data = np.random.randn(1000)

# Plot the histogram
plt.hist(data, bins=30, edgecolor='black')
plt.title('Histogram of Normally Distributed Variable')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
